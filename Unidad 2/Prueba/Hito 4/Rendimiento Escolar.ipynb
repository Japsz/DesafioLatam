# %% [markdown]
# # Hito 1, Desafío 2: Rendimiento Escolar
#
# ## __Enunciado:__
# Lo contactan de una escuela Portuguesa para generar un modelo que identifique aquellos
# alumnos que presentan un bajo desempeño académico, medido en el promedio final del año
# escolar. Para ello le envían un archivo con registros sociodemográficos y conductuales de
# los alumnos de dos escuelas para perfilar a los estudiantes.</br>
#
# De manera adicional la psicopedagoga sugiere inspeccionar una batería de preguntas
# asociadas a aspectos ambientales del alumno (de <code>famrel</code> a <code>health</code>) y ver si éstas se
# pueden abstraer en categorías latentes.
#
# ### __Descripción de la base de datos__
# Las variables que componen esta base se detallan a continuación:
#
# <ul>
# <li><code>school</code> : Escuela del estudiante. (binaria: 'GP' - Gabriel Pereira o 'MS' - Mousinho da Silveira)</li>
#
# <li><code>sex</code> : Sexo del estudiante. (binaria: 'F' - Mujer o 'M' - Hombre)</li>
#
# <li><code>age</code> : Edad del estudiante. (numérica: de 15 a 22)</li>
#
# <li><code>address</code> : Ubicación de la casa del estudiante. (binaria: 'U' - urbana o 'R' - rural)</li>
#
# <li><code>famsize</code> : Tamaño de la familia. (binaria: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)</li>
#
# <li><code>Pstatus</code> : Estado cohabitacional de los padres. (binaria: 'T' - cohabitando juntos o 'A' - viviendo separados)</li>
#
# <li><code>Medu</code> : Nivel educacional de la madre. (numérica: 0 - ninguno, 1 - educación básica (4to), 2 - de 5to a 9, 3 - educación media, o 4 - educación superior).</li>
#
# <li><code>Fedu</code> : Nivel educacional del padre. (numérica: 0 - ninguno, 1 - educación básica (4to), 2 - de 5to a 9, 3 - educación media, o 4 - educación superior).</li>
#
# <li><code>Mjob</code> : Ocupación de la madre. (nominal: 'teacher' profesora, 'health' relacionada a salud, 'services' (e.g. administración pública o policía), 'at_home' en casa u 'other' otra).</li>
#
# <li><code>Fjob</code> : Ocupación del padre (nominal: 'teacher' profesor, 'health' relacionado a salud, 'services' (e.g. administración pública o policía), 'at_home' en casa u 'other' otra).</li>
#
# <li><code>reason</code> : Razón para escoger la escuela (nominal: 'home' cercano a casa, 'reputation' reputación de la escuela, 'course' preferencia de cursos u 'other' otra)</li>
#
# <li><code>guardian</code> : Apoderado del estudiante (nominal: 'mother' madre, 'father' padre u 'other' otro)</li>
#
# <li><code>traveltime</code> : Tiempo de viaje entre hogar y colegio. (numeric: 1 - <15 min., 2 - 15 a 30 min., 3 - 30 min. a 1 hora, or 4 - >1 hora).</li>
#
# <li><code>studytime</code> : Horas semanales dedicadas al estudio. (numérica: 1 - <2 horas, 2 - 2 a 5 horas, 3 - 5 a 10 horas, o 4 - >10 horas)</li>
#
# <li><code>failures</code> : Número de clases reprobadas. (numérica: n si 1<=n<3, de lo contrario 4)</li>
#
# <li><code>schoolsup</code> : Apoyo educacional del colegio. (binaria: si o no)</li>
#
# <li><code>famsup</code> : Apoyo educacional familiar. (binaria: si o no)</li>
#
# <li><code>paid</code> : Clases particulares pagadas (matemáticas o portugués) (binaria: si o no)</li>
#
# <li><code>activities</code> : Actividades extracurriculares. (binaria: si o no)</li>
#
# <li><code>nursery</code> : Asistió a guardería infantil. (binaria: si o no)</li>
#
# <li><code>higher</code> : Desea proseguir estudios superiores (binaria: si o no)</li>
#
# <li><code>internet</code> : Acceso a internet desde el hogar (binaria: si o no)</li>
#
# <li><code>romantic</code> : Relación romántica (binaria: si o no)</li>
#
# <li><code>famrel</code> : Calidad de las relaciones familiares. (numérica: de 1 - muy malas a 5 - excelentes)</li>
#
# <li><code>freetime</code> : Tiempo libre fuera del colegio (numérica: de 1 - muy poco a 5 - mucho)</li>
#
# <li><code>goout</code> : Salidas con amigos (numérica: de 1 - muy pocas a 5 - muchas)</li>
#
# <li><code>Dalc</code> : Consumo de alcohol en día de semana (numérica: de 1 - muy bajo a 5 - muy alto)</li>
#
# <li><code>Walc</code> : Consumo de alcohol en fines de semana (numérica: de 1 - muy bajo a 5 - muy alto)</li>
#
# <li><code>health</code> : Estado de salud actual (numérica: from 1 - muy malo to 5 - muy bueno)</li>
#
# <li><code>absences</code> : Cantidad de ausencias escolares (numérica: de 0 a 93)</li>
#
# <li><code>G1</code> : Notas durante el primer semestre (numérica: de 0 a 20). Este es uno de sus vectores objetivos para el modelo descriptivo.</li>
# <li><code>G2</code> : Notas durante el segundo semestre (numérica: de 0 a 20). Este es uno de sus vectores objetivos para el modelo descriptivo.</li>
#
# <li><code>G3</code> : Promedio final (numérica: de 0 a 20). Este es uno de sus vectores objetivos para el
# modelo descriptivo y el vector a predecir en el modelo predictivo.</li>
# </ul>
#
# ### __Aspectos adicionales a considerar__
# <li>La base de datos presenta una serie de anomalías. En la escuela no tienen buenas
# prácticas sobre cómo ingresar datos, por lo que existen datos perdidos que están
# registrados bajo tres categorías: nulidade, sem validade, zero. De manera adicional,
# hay 3 variables numéricas que se registraron como strings, cuya interpretación en
# <code>pandas</code> devuelve una estructura de datos genérica. Finalmente, la base está con un
# encoding distinto al normal y los delimitadores son distintos.</li>
# <li>Para simplificar el análisis y su posterior inclusión en un modelo predictivo, se
# sugiere recodificar las variables binarias como 0 y 1. Se recomienda seguir en
# criterio de asignarle 1 a aquellas categorías minoritarias.</li>
# <li>El procedimiento también debe aplicarse para aquellas variables nominales con más
# de 2 categorías siguiendo la misma lógica.</li>
# <li>En la parte de modelación descriptiva, se deben generar modelos utilizando todos
# los predictores por cada una de las notas registradas en <code>G1</code>, <code>G2</code> y <code>G3</code>.</li>
# <li>Para la parte de modelación predictiva, se debe generar un modelo para predecir las
# notas en <code>G3</code>.</li>

# %% [markdown]
# ## __Preliminares__
#
# ### __Descripción y Objetivo__:
#
# La idea es perfilar a los estudiantes mediante variables socioeconómicas, demográficas y conductuales para poder predecir el desempeño académico hasta el fin de año. Además se pide analizar la posibilidad de abstraer en categorias latentes un cojunto de variables ambientales del alumno.
#
# ### __Solucion__:
#
# - Para perfilar a los estudiantes se empleara un módelo predictivo en base a las notas registradas durante los semestres. Para ello se planeta realizar regresiones lineales múltiples por separado y considerando todas las variables presentes (módelos saturados), para luego depurar el modelo en base a la incidencia de cada parametro y el p-value obtenido para cada regresor.
#
# - Para evaluar el ajuste de los modelos, se interpretaran los valores de los estadísticos de bondad de ajuste $R-Cuadrado$ y $Prueba-F$. Además de hacer las pruebas respectivas de eficiencia para los distintos modelos que se generen durante la depuración.
#
#
# - Por otra parte, en base a los modelos conseguidos se evaluará la incidencia de las categorías latentes pedidas, y se evaluará para los distintos modelos evaluades en la sección anterior.

# %% [markdown]
# ## __Aspectos computacionales__
#
# __Librerias de Python a utilizar:__
# <ul>
# <li>pandas: para la manipulación de las tablas de datos a través de los DataFrame y arrays.</li>
# <li>numpy: para la conversión de datos en matrices/vectores y la manipulación de estos en los cálculos de alguans métricas.</li>
# <li>sklearn: para aplicar el algoritmo de aprendizaje supervisado, selección de matrices y vectores train/test, estandarización, entre otros.
# <ul>
#         <li> <code>Linear-Model</code>: <code>LinearRegression</code></li>
#         <li> <code>Model-Selection</code>: <code>Train-Test_split</code></li>
#         <li> <code>sklearn-preprocessing</code>: <code>StandardScaler</code></li>
#         <li> <code>metrics</code>:
#         <ul>
#             <li><code>mean_squared_error</code></li>
#             <li><code>r2_score</code></li>
#         </ul></li>
#         <li> <code>model_selection</code>: <code>cross_val_score</code></li>
#             </ul>
# </li>
# <li>Seaborn: para algunas descripciones estadísticas.</li>
# <li>Statsmodels: para algunos cálculos estadísticos.</li>
# <li>Matplotlib: para la generación de gráficos.</li>
# <li>Warnings: para evitar avisos de precaución.</li>
#
# __Funciones generadas:__
#
# - Función __tipo_variable__: devuelve el nombre y el tipo de variable para todas las variables en la base de datos.
# - Función __descripcion_variable__: devuelve las estadísticas descriptivas de todas las variables en la base de datos.
# - Función __histograma__: genera el histograma de frecuencia de datos y grafica la media.
# - Función __distribucion_frecuencias__: genera el gráfico de barra.
# - Función __report_scores__: imprime las métricas del Error Cuadrático promedio y R2.
#
#
# ### __Preprocesamiento de datos:__
#
# __Análsis exploratorio__: para determinar la cantidad de casos, estudiar las variables presentes y obtener las medidas descriptivas de los datos con los que vamos a trabajar.
#
# __Data Clean__: Dado que la base de datos presenta una serie de anomalías, se procederá a la limpieza y estandarización de los datos, en primera instancia transformando los datos pérdidos que estan registrados bajo tres categorias: nulidade, sem validade, zero. También se ralizaran las respectivas recodificaciones acorde a las nomenclaturas indicadas y binarozación de las variables dicotómicas.
#
# __Data Process__: se estudiaran las correlaciones para determinar la intensidad de las asociaciones entre las variables de la base de datos y su posible redundancia. Luego, se realizaran modelos de regresión lineal saturados (cosniderando todas las variables) pero antes de plantear las regresiones, se analizará la posible formación de factores latentes con las variables de aspectos ambientales del alumno; de determinarse la existencia de dichos factores estos seran cosniderados como variables independientes en las regresiones y posterior modelo predictivo. Para el modelo predictivo, se segmentará nuestra base de datos en entrenamiento y validación siguiendo el criterio de guardar el 30% de la muestra como validación. De ser necesario, se estandarizaran las variables para homogeneizarlas y facilitar la comparación entre atributos. Aplicamos el modelo y evaluamos las métricas de ajuste.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import statsmodels.api as sm
import statsmodels.formula.api as smf

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import cross_val_score

import factor_analyzer as factor
import missingno as msngo
import warnings

warnings.filterwarnings('ignore')

plt.rcParams["figure.figsize"] = (10, 6) # Tamaño gráficos

# %% [markdown]
# ## __Descripción__
#
# ## Visualización de Conjunto de datos
# Partiremos por refactorizar los datos conseguidos

# %%
df = pd.read_csv('students.csv', delimiter='|').drop(columns=['Unnamed: 0'])
parsedDf = df.copy()
# Parseamos todas las columnas:
for col in df.columns:
    if parsedDf[col].dtype == 'object':
        # Se quitan las comillas dobles y se transforman los datos nulos
        parsedDf[col] = parsedDf[col].apply(lambda x: x.replace('"', '')).replace(['nulidade', 'sem validade', 'zero'], [float("NaN"), float("NaN"),float("NaN")])
# Convertimos aquellas variables 
intCols = ['age', 'Medu', 'Fedu', 'traveltime', 'studytime', 'failures', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'absences', 'G1', 'G3']
for intCol in intCols:
    parsedDf[intCol] = pd.to_numeric(parsedDf[intCol], downcast='integer')
parsedDf.dtypes
# Out:
# school         object
# sex            object
# age           float64
# address        object
# famsize        object
# Pstatus        object
# Medu          float64
# Fedu          float64
# Mjob           object
# Fjob           object
# reason         object
# guardian       object
# traveltime    float64
# studytime     float64
# failures      float64
# schoolsup      object
# famsup         object
# paid           object
# activities     object
# nursery        object
# higher         object
# internet       object
# romantic       object
# famrel        float64
# freetime      float64
# goout         float64
# Dalc          float64
# Walc          float64
# health         object
# absences      float64
# G1            float64
# G2              int64
# G3            float64
# dtype: object

# %% [markdown]
# Hacemos un Análisis de los datos perdidos

# %%
# Vemos las variables perdidas
msngo.matrix(parsedDf, labels=True)
msngo.matrix(parsedDf.dropna(), labels=True)
# Sólo dejamos los registros completos
parsedDf = parsedDf.dropna()

# %% [markdown]
# Vemos que hay varias columnas que presentan datos perdidos, siendo 30 la columna con mas pérdida. Luego de quitar todos los registors quedó con 284 observaciones, es decir, 111 perdidas

# %% [markdown]
# Ahora que traspásamos aquellas columnas que podían ser números a los tipos correspondientes podemos hacer un análisis de como se ve el vector objetivo según las demas variables.

# %%
# Declaramos un nuevo df para que tenga las columnas nuevas
refactoredDf = pd.get_dummies(parsedDf)
# Creamos los graficos para ver la relación de G1, G2, y G3 con el resto de las variables
fig, ax = plt.subplots(len(parsedDf.columns) - 3, 3)
# ajustamos el tamaño de la figura
plt.figure(figsize=(20, 6*len(parsedDf.columns)))
# Iteramos sobre las columnas
for i, col in enumerate(parsedDf.columns):
    if parsedDf[col].dtype == 'object':
        frequency = parsedDf[col].value_counts()
        # Se grafica la frecuencia de las notas diferenciados según las columnas categóricas
        sns.countplot(x='G1', data=parsedDf, hue=col, ax=ax[i][0])
        sns.countplot(x='G2', data=parsedDf, hue=col, ax=ax[i][1])
        sns.countplot(x='G3', data=parsedDf, hue=col, ax=ax[i][2])
    else:
        # Las variables numéricas las hacemos boxplot
        if col not in ['G2', 'G3', 'G1']:
            sns.boxplot(x='G1', y=col, data=parsedDf, ax=ax[i][0])
            sns.boxplot(x='G2', y=col, data=parsedDf, ax=ax[i][1])
            sns.boxplot(x='G3', y=col, data=parsedDf, ax=ax[i][2])

# %% [markdown]
# Podemos observar que la gran mayoría de las variables mantienen su distribución entre los tres periodos de notas, y pareciera que normalmente el periodo 'G3' es el que mas diferencia tiene con respecto a 'G2' y 'G1'.
#
# Los análisis mas interesantes son:
#
# <ul>
# <li>Para <code>studytime</code> Se puede observar que el primer periodo presenta que casi todos tenían una canntidad de horas altas, pero para los con notas mas bajas este tiempo disminuye hacia el último periodo</li>
# <li>Con <code>internet</code> podemos notar que la mayoría de las personas que tienen notas bajo el promedio no tienen acceso a internet.</li>
# <li>a traves de <code>Dalc</code> se puede ver que el consumo de alcohol durante la semana aumenta hacia el último periodo en las personas que tienen bajas notas.</li>
# </ul>

# %% [markdown]
# ## __Hito 3, Modelación Descriptiva__

# %% [markdown]
# En base a lo pedido, analizaremos las columnas
# <ul>
# <li><code>famrel</code></li> <li><code>freetime</code></li> <li><code>goout</code></li> <li><code>Dalc</code></li> <li><code>Walc</code></li> <li><code>health</code></li></ul>
# para ver si es posible extraer categorías latentes.

# %%
latDf = parsedDf.loc[:,'famrel':'health']
for i in latDf.columns:
    latDf[i] = latDf[i].astype(int)
factor.calculate_bartlett_sphericity(latDf)
# Out:
# (264.4978629665065, 6.038167101269206e-48)

# %% [markdown]
# Esto entrega un chi cuadrado relativamente alto y un p-value cercano a 0, lo que nos permite decir que nuestra matriz no es igual a una matriz identidad. Continuamos con la prueba KMO.

# %%
pd.Series(factor.calculate_kmo(latDf)[0], index=latDf.columns)
# Out:
# famrel      0.501733
# freetime    0.576923
# goout       0.616840
# Dalc        0.586642
# Walc        0.555409
# health      0.592659
# dtype: float64

# %% [markdown]
# Esto nos indica que no es posible extraer valores latentes pues ningún factor presenta un valor superior a 0.7

# %% [markdown]
# ### Creación de modelos
#
# Analizaremos las correlaciones existentes

# %%
plt.figure(figsize=(20, 15))

corrMatrix = refactoredDf.corr()

filteredMatrix = corrMatrix[(corrMatrix > 0.1) | (corrMatrix < -0.1)]

sns.heatmap(filteredMatrix, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Vemos que para nuestras variables de interés <code>G1, G2 y G3</code> se observa una proporcionalidad directa fuerte entre ellas, seguida por una de bastante menor intensidad <code>Medu</code>. También se aprecia una proporcionalidad inversa considerable con <code>failures</code> seguida por <code>goout</code>.

# %% [markdown]
# A continuación haremos las regresiónes lineales para nuestras variables de interés usando todos los factores.

# %%
for i in ['G1', 'G2', 'G3']:
    model = smf.ols('{} ~ '.format(i) + '+ '.join(list(filter(lambda x: x != i, refactoredDf.columns))), data=refactoredDf).fit()
    print('Modelo para {}'.format(i))
    print(model.summary())
# Out:
# Modelo para G1
#                             OLS Regression Results
# ...
# Dep. Variable:                     G1   R-squared:                       0.795
# Model:                            OLS   Adj. R-squared:                  0.757
# Method:                 Least Squares   F-statistic:                     21.08
# Date:                Mon, 27 Sep 2021   Prob (F-statistic):           2.31e-60
# Time:                        00:08:52   Log-Likelihood:                -515.51
# No. Observations:                 284   AIC:                             1121.
# Df Residuals:                     239   BIC:                             1285.
# Df Model:                          44
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            -0.0322      0.232     -0.139      0.890      -0.490       0.426
# ...

# %% [markdown]
# Podemos observar que los 3 modelos tienen estadísticas de bondad del modelo bastante parecidas. siendo las de <code>G2</code> las mejores.

# %% [markdown]
# ## __Hito 4, Modelos Predictivos__
#
# A continuación haremos el análisis de los mdoelos y compararemos en base a los estadísticos de bondad de los modelos.

# %%
# Definimos una función para evaluar el desempeño del modelo obtenido. Retorna 
def getLinearModelAnalysis(df, cols, y):
    # se generan los subconjuntos de entrenamiento
    x_train, x_test, y_train, y_test = train_test_split(df.loc[:,cols], df[y], test_size=.33)
    # se estandarizan las matrices
    x_train_std = StandardScaler().fit_transform(x_train)
    x_test_std = StandardScaler().fit_transform(x_test)

    # Se implementa el modelo usando nuesto bootstrap de sklearn
    default_model = LinearRegression().fit(x_train_std, y_train)

    # se consiguen las predicciones para el conjunto de testeo
    y_test_predict = default_model.predict(x_test_std)

    # se reportan las Métricas
    m1_mse = mean_squared_error(y_test, y_test_predict).round(2)
    m1_r2 = r2_score(y_test, y_test_predict).round(2)
    print("Mean Squared Error: ", m1_mse)
    print("R-cuadrado: ", m1_r2)
    return default_model

# %% [markdown]
# Haremos un modelo con todos los atributos, el siguiente en que depuraremos todos aquellos atributos con p-value < 0.05 y uno mas con valores cuadráticos.

# %%
model = smf.ols('G3 ~ ' + '+ '.join(list(filter(lambda x: x != 'G3', refactoredDf.columns))), data=refactoredDf).fit()
# Conseguir las columnas 
depuratedCols = list(map(lambda x: refactoredDf.columns[x[0]-2] ,list(filter(lambda x: x[1] < 0.05, enumerate(model.pvalues)))))
# Ver modelo con todos los datos
print("Modelo con todos los atributos: ")
allModel = getLinearModelAnalysis(refactoredDf, list(filter(lambda x: x != 'G3', refactoredDf.columns)), 'G3')
print("=======================")
# Ver modelo filtrado por pvalues
print("Modelo con atributos filtrados: ")
depuratedModel = getLinearModelAnalysis(refactoredDf, depuratedCols, 'G3')
print("=======================")
# Out:
# Modelo con todos los atributos:
# Mean Squared Error:  2.679641154130937e+26
# R-cuadrado:  -1.5602942515536156e+25
# ...
# Modelo con atributos filtrados:
# Mean Squared Error:  3.64
# R-cuadrado:  0.8
# ...

# %% [markdown]
# Vemos que al eliminar los atributos hay un aumento del R-cuadrado, pero un mayo MSE lo que es bastante malo. La
#
# A continuación intentaremos ver si es posible eliminar mas columnas.

# %%
model = smf.ols('G3 ~ ' + '+ '.join(depuratedCols), data=refactoredDf).fit()
model.pvalues
# Out:
# Intercept    1.687676e-04
# failures     1.880407e-02
# Dalc         2.141397e-01
# Walc         3.085545e-02
# absences     1.080267e-02
# G1           5.683005e-03
# G2           3.539856e-43
# dtype: float64
