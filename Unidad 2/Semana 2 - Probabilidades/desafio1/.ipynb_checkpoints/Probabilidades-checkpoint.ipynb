# %% [markdown]
# # Desafío - Calculando probabilidades
# #### Desafio 4
# <ul>
#     <li>Importe pandas y numpy siguiendo las convenciones.</li>
#     <li>Lea la base de datos worldcup2014.csv y asígnela a un objeto df.</li>
#     <li>Solicite las primeras 5 observaciones con head.</li>
# </ul>

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('./worldcup2014.csv')
df.head(5)
# Out:
#           team     continent group  group_pos  cantidad_juegos  \
# 0       Brazil  southamerica     A          1                3
# 1       Mexico  northamerica     A          2                3
# 2      Croatia        europe     A          3                3
# 3     Cameroon        africa     A          4                3
# 4  Netherlands        europe     B          1                3
#
#    juegos_ganados  juegos_empatados  juegos_perdidos  goles_favor  \
# 0               2                 1                0            7
# 1               2                 1                0            4
# 2               1                 0                2            6
# 3               0                 0                3            1
# 4               3                 0                0           10
#
#    goles_contra goles_diferencia  puntos  clasificado
# 0             2                5       7            1
# 1             1                3       7            1
# 2             6                0       3            0
# 3             9               −8       0            0
# 4             3                7       9            1

# %% [markdown]
# #### Desafio 2
# Utilizando value_counts. Responda lo siguiente:
# <ul>
#     <li> ¿Cuál es el continente con una mayor presencia en la muestra?</li>
#     <li>¿Cuál es la probabilidad de elegir un equipo asiático al azar?</li>
#     <li> ¿Cuál es la probabilidad de elegir un equipo africano al azar?</li>
# </ul>

# %%
continents = df['continent'].value_counts()

print(f'Mayor presencia es europa')
totalMuestra = continents.sum()
probAsia = continents['asia']/totalMuestra
print(f'Probabilidad de elgir un equipo asiatico es de ${str()}')

print(f'Probabilidad de elgir un equipo africano es de ${str(continents['africa']/totalMuestra)}')
# Out:
#   File "<ipython-input-9-e1f4cf0429fc>", line 6
#     print(f'Probabilidad de elgir un equipo asiatico es de ${str(continents['asia']/totalMuestra)}')
#                                                                              ^
# SyntaxError: invalid syntax
