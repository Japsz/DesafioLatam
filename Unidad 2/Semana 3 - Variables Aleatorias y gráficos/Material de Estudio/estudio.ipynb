# %%
import matplotlib.pyplot as plt
import numpy as np

x_axis = np.linspace(-3,3)
y_axis = x_axis**3 - 3
plt.plot(x_axis, y_axis)

# %%
import pandas as pd

df = pd.read_csv('qog_std_cs_jan18.csv')
df.describe
# Out:
# <bound method NDFrame.describe of      ccode        cname ccodealp  ccodecow  ccodewb        version  aid_cpnc  \
# 0        4  Afghanistan      AFG     700.0      4.0  QoGStdCSJan18       NaN
# 1        8      Albania      ALB     339.0      8.0  QoGStdCSJan18       NaN
# 2       12      Algeria      DZA     615.0     12.0  QoGStdCSJan18       NaN
# 3       20      Andorra      AND     232.0     20.0  QoGStdCSJan18       NaN
# 4       24       Angola      AGO     540.0     24.0  QoGStdCSJan18       NaN
# ..     ...          ...      ...       ...      ...            ...       ...
# 189    860   Uzbekistan      UZB     704.0    860.0  QoGStdCSJan18       NaN
# 190    862    Venezuela      VEN     101.0    862.0  QoGStdCSJan18       NaN
# 191    882        Samoa      WSM     990.0    882.0  QoGStdCSJan18       NaN
# 192    887        Yemen      YEM     679.0    887.0  QoGStdCSJan18       NaN
# 193    894       Zambia      ZMB     551.0    894.0  QoGStdCSJan18       NaN
#
# ...

# %%
hdi = df['undp_hdi'].dropna()

plt.hist(hdi, color='tomato')
line = plt.axvline(hdi.mean(), color='gray', lw=3)
line.label = 'Hello'
plt.xlabel('HDI')
plt.ylabel('Frecuencia')
plt.title('Grafico bacán')
# Out:
# Text(0.5, 1.0, 'Grafico bacán')

# %%
sample = pd.read_csv('subsample_isz.csv')
subsample = pd.read_csv('../desafio1/subsample_demo.csv')
sample['ht_region'].value_counts()
# Out:
# SubSaharian      25
# WesternDem       18
# EastEurope       16
# LatAm             8
# NorthAfrica       8
# Caribbean         6
# SouthEastAsia     6
# SouthAsia         5
# Pacific           3
# EastAsia          2
# Name: ht_region, dtype: int64

# %%
subsample['ht_region'].value_counts()
# Out:
# 4     27
# 5     19
# 1     12
# 2     10
# 9      6
# 8      6
# 7      6
# 3      5
# 10     4
# 6      2
# Name: ht_region, dtype: int64
